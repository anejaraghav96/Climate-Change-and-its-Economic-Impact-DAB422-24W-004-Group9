# %% [markdown]
# ## PRODUCTIVITY FOR 5 PROVINCES ##

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
# ignore all warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# to load productivity data

productivity = pd.read_csv('combined_productivity_clean.csv') # 

productivity.head()
# Out:
#          Date provincename  Utilities  Construction  Manufacturing  \
# 0  1997-01-01      Alberta   1.485804     17.399965      18.590137
# 1  1997-02-01      Alberta   1.471049     17.695034      19.034434
# 2  1997-03-01      Alberta   1.411428     16.630237      19.274297
# 3  1997-04-01      Alberta   1.465141     16.642340      19.578348
# 4  1997-05-01      Alberta   1.623730     18.062713      19.621579
#
#    Transportation and warehousing  Educational services  \
# 0                       13.340542             11.588955
# 1                       13.617536             11.890582
# 2                       14.453078             11.962199
# 3                       13.256295             12.456337
# 4                       13.355093             12.027437
#
#    Health care and social assistance  Accommodation and food services  \
# 0                          13.343328                         3.872117
# 1                          13.739512                         3.734915
# 2                          13.321957                         3.790906
# 3                          14.011986                         4.100418
# 4                          13.889241                         4.119427
#
#    Other services except public administration  ...  \
# 0                                     5.368650  ...
# 1                                     5.496880  ...
# 2                                     5.773114  ...
# 3                                     5.658535  ...
# 4                                     5.613666  ...
#
#    Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction  \
# 0                                         362.713936
# 1                                         368.185093
# 2                                         385.806995
# 3                                         393.425984
# 4                                         385.021311
#
#    Wholesale trade Retail trade  \
# 0                     17.907676
# 1                     17.586050
# 2                     17.377787
# 3                     17.690151
# 4                     16.922974
#
#    Finance and insurance, real estate and rental and leasing  \
# 0                                          24.135310
# 1                                          23.488937
# 2                                          22.444308
# 3                                          22.302734
# 4                                          24.040353
#
#    Professional scientific and technical services  \
# 0                                       15.578428
# 1                                       16.206769
# 2                                       15.380479
# 3                                       15.873826
# 4                                       15.534059
#
#    Information culture and recreation  Population   GeoUID  census_year_ref  \
# 0                            7.600796      7662.0  4801003             CA16
# 1                            7.283954      7662.0  4801003             CA16
# 2                            7.683184      7662.0  4801003             CA16
# 3                            7.369425      7662.0  4801003             CA16
# 4                            7.534485      7662.0  4801003             CA16
#
#                                       Dominant_NAICS colourval
# 0  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
# 1  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
# 2  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
# 3  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
# 4  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
#
# [5 rows x 21 columns]

# %%
productivity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1342800 entries, 0 to 1342799
# Data columns (total 21 columns):
#  #   Column                                                                             Non-Null Count    Dtype
# ---  ------                                                                             --------------    -----
#  0   Date                                                                               1342800 non-null  object
#  1   provincename                                                                       1342800 non-null  object
#  2   Utilities                                                                          1342800 non-null  float64
#  3   Construction                                                                       1342800 non-null  float64
#  4   Manufacturing                                                                      1342800 non-null  float64
#  5   Transportation and warehousing                                                     1342800 non-null  float64
#  6   Educational services                                                               1342800 non-null  float64
#  7   Health care and social assistance                                                  1342800 non-null  float64
#  8   Accommodation and food services                                                    1342800 non-null  float64
#  9   Other services except public administration                                        1342800 non-null  float64
#  10  Public administration                                                              1342800 non-null  float64
#  11  Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction  1342800 non-null  float64
#  12  Wholesale trade Retail trade                                                       1342800 non-null  float64
#  13  Finance and insurance, real estate and rental and leasing                          1342800 non-null  float64
#  14  Professional scientific and technical services                                     1342800 non-null  float64
#  15  Information culture and recreation                                                 1342800 non-null  float64
#  16  Population                                                                         1342800 non-null  float64
#  17  GeoUID                                                                             1342800 non-null  int64
#  18  census_year_ref                                                                    1342800 non-null  object
#  19  Dominant_NAICS                                                                     1342800 non-null  object
#  20  colourval                                                                          1342800 non-null  object
# dtypes: float64(15), int64(1), object(5)
# memory usage: 215.1+ MB

# %%
#checking for missing values
productivity.isnull().sum()
# Out:
# Date                                                                                 0
# provincename                                                                         0
# Utilities                                                                            0
# Construction                                                                         0
# Manufacturing                                                                        0
# Transportation and warehousing                                                       0
# Educational services                                                                 0
# Health care and social assistance                                                    0
# Accommodation and food services                                                      0
# Other services except public administration                                          0
# Public administration                                                                0
# Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction    0
# Wholesale trade Retail trade                                                         0
# Finance and insurance, real estate and rental and leasing                            0
# Professional scientific and technical services                                       0
# Information culture and recreation                                                   0
# Population                                                                           0
# GeoUID                                                                               0
# census_year_ref                                                                      0
# Dominant_NAICS                                                                       0
# colourval                                                                            0
# dtype: int64

# %%
# update data column to datatime format
productivity['Date/Time'] = pd.to_datetime(productivity['Date'])
productivity
# Out:
#                Date  provincename  Utilities  Construction  Manufacturing  \
# 0        1997-01-01       Alberta   1.485804     17.399965      18.590137
# 1        1997-02-01       Alberta   1.471049     17.695034      19.034434
# 2        1997-03-01       Alberta   1.411428     16.630237      19.274297
# 3        1997-04-01       Alberta   1.465141     16.642340      19.578348
# 4        1997-05-01       Alberta   1.623730     18.062713      19.621579
# ...             ...           ...        ...           ...            ...
# 1342795  2021-08-01  Saskatchewan   2.829359      0.909181       1.765590
# 1342796  2021-09-01  Saskatchewan   3.860524      0.861926       1.813471
# 1342797  2021-10-01  Saskatchewan   3.350091      0.890384       1.686692
# 1342798  2021-11-01  Saskatchewan   3.166056      0.886212       1.862323
# 1342799  2021-12-01  Saskatchewan   3.617298      0.904056       1.806240
#
#          Transportation and warehousing  Educational services  \
# 0                             13.340542             11.588955
# 1                             13.617536             11.890582
# 2                             14.453078             11.962199
# 3                             13.256295             12.456337
# 4                             13.355093             12.027437
# ...                                 ...                   ...
# 1342795                        0.000000              2.069695
# 1342796                        0.000000              2.696269
# 1342797                        0.000000              2.679829
# 1342798                        0.000000              2.630175
# 1342799                        0.000000              2.707189
#
#          Health care and social assistance  Accommodation and food services  \
# 0                                13.343328                         3.872117
# 1                                13.739512                         3.734915
# 2                                13.321957                         3.790906
# 3                                14.011986                         4.100418
# 4                                13.889241                         4.119427
# ...                                    ...                              ...
# 1342795                           2.977844                         0.000000
# 1342796                           3.098698                         0.000000
# 1342797                           3.119581                         0.000000
# 1342798                           3.122140                         0.000000
# 1342799                           3.093373                         0.000000
#
#          Other services except public administration  ...  \
# 0                                           5.368650  ...
# 1                                           5.496880  ...
# 2                                           5.773114  ...
# 3                                           5.658535  ...
# 4                                           5.613666  ...
# ...                                              ...  ...
# 1342795                                     0.000000  ...
# 1342796                                     0.000000  ...
# 1342797                                     0.000000  ...
# 1342798                                     0.000000  ...
# 1342799                                     0.000000  ...
#
#          Wholesale trade Retail trade  \
# 0                           17.907676
# 1                           17.586050
# 2                           17.377787
# 3                           17.690151
# 4                           16.922974
# ...                               ...
# 1342795                      0.000000
# 1342796                      0.000000
# 1342797                      0.000000
# 1342798                      0.000000
# 1342799                      0.000000
#
#          Finance and insurance, real estate and rental and leasing  \
# 0                                                24.135310
# 1                                                23.488937
# 2                                                22.444308
# 3                                                22.302734
# 4                                                24.040353
# ...                                                    ...
# 1342795                                           0.000000
# 1342796                                           0.000000
# 1342797                                           0.000000
# 1342798                                           0.000000
# 1342799                                           0.000000
#
#          Professional scientific and technical services  \
# 0                                             15.578428
# 1                                             16.206769
# 2                                             15.380479
# 3                                             15.873826
# 4                                             15.534059
# ...                                                 ...
# 1342795                                        0.000000
# 1342796                                        0.000000
# 1342797                                        0.000000
# 1342798                                        0.000000
# 1342799                                        0.000000
#
#          Information culture and recreation  Population   GeoUID  \
# 0                                  7.600796      7662.0  4801003
# 1                                  7.283954      7662.0  4801003
# 2                                  7.683184      7662.0  4801003
# 3                                  7.369425      7662.0  4801003
# 4                                  7.534485      7662.0  4801003
# ...                                     ...         ...      ...
# 1342795                            0.000000      1061.0  4718852
# 1342796                            0.000000      1061.0  4718852
# 1342797                            0.000000      1061.0  4718852
# 1342798                            0.000000      1061.0  4718852
# 1342799                            0.000000      1061.0  4718852
#
#          census_year_ref                                     Dominant_NAICS  \
# 0                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# 1                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# 2                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# 3                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# 4                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# ...                  ...                                                ...
# 1342795             CA16                          X91.Public.administration
# 1342796             CA16                          X91.Public.administration
# 1342797             CA16                          X91.Public.administration
# 1342798             CA16                          X91.Public.administration
# 1342799             CA16                          X91.Public.administration
#
#         colourval  Date/Time
# 0         #8DA0CB 1997-01-01
# 1         #8DA0CB 1997-02-01
# 2         #8DA0CB 1997-03-01
# 3         #8DA0CB 1997-04-01
# 4         #8DA0CB 1997-05-01
# ...           ...        ...
# 1342795   #FC8D62 2021-08-01
# 1342796   #FC8D62 2021-09-01
# 1342797   #FC8D62 2021-10-01
# 1342798   #FC8D62 2021-11-01
# 1342799   #FC8D62 2021-12-01
#
# [1342800 rows x 22 columns]

# %%
# to check  productivity date range
print(productivity['Date/Time'].min())
print(productivity['Date/Time'].max())
# Out:
# 1997-01-01 00:00:00
# 2021-12-01 00:00:00

# %%
# to remove 1997 data to be consistent with the weather dataset
prod_clean = productivity[productivity['Date/Time'] >= '1998-01-01']
print(prod_clean['Date/Time'].min())
print(prod_clean['Date/Time'].max())
# Out:
# 1998-01-01 00:00:00
# 2021-12-01 00:00:00

# %%
# to filter 5 provinces
filter = ['Quebec', 'Ontario', 'British Columbia', 'Alberta', 'Saskatchewan']
prod_clean = prod_clean[prod_clean['provincename'].isin(filter)]
print(prod_clean['provincename'].unique())
print(prod_clean.info())
# Out:
# ['Alberta' 'British Columbia' 'Ontario' 'Quebec' 'Saskatchewan']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 993600 entries, 12 to 1342799
# Data columns (total 22 columns):
#  #   Column                                                                             Non-Null Count   Dtype
# ---  ------                                                                             --------------   -----
#  0   Date                                                                               993600 non-null  object
#  1   provincename                                                                       993600 non-null  object
#  2   Utilities                                                                          993600 non-null  float64
#  3   Construction                                                                       993600 non-null  float64
#  4   Manufacturing                                                                      993600 non-null  float64
#  5   Transportation and warehousing                                                     993600 non-null  float64
#  6   Educational services                                                               993600 non-null  float64
#  7   Health care and social assistance                                                  993600 non-null  float64
#  8   Accommodation and food services                                                    993600 non-null  float64
#  9   Other services except public administration                                        993600 non-null  float64
#  10  Public administration                                                              993600 non-null  float64
#  11  Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction  993600 non-null  float64
#  12  Wholesale trade Retail trade                                                       993600 non-null  float64
#  13  Finance and insurance, real estate and rental and leasing                          993600 non-null  float64
#  14  Professional scientific and technical services                                     993600 non-null  float64
#  15  Information culture and recreation                                                 993600 non-null  float64
#  16  Population                                                                         993600 non-null  float64
#  17  GeoUID                                                                             993600 non-null  int64
#  18  census_year_ref                                                                    993600 non-null  object
#  19  Dominant_NAICS                                                                     993600 non-null  object
#  20  colourval                                                                          993600 non-null  object
#  21  Date/Time                                                                          993600 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(15), int64(1), object(5)
# memory usage: 174.4+ MB
# None

# %%
# to load weather_geography_merged data
weather_1998_2018Feb = pd.read_csv('weather_geography_merged_1998_to_2018Feb.csv')
weather_2018_2024 = pd.read_csv('final_merged_weather_2018_2024.csv')

# %%
# to convert the "Date/Time" column to date format
weather_1998_2018Feb['Date/Time'] = pd.to_datetime(weather_1998_2018Feb['Date/Time'])
weather_2018_2024['Date/Time'] = pd.to_datetime(weather_2018_2024['Date/Time'])

# to remove overlapping data (2018 Jan and Feb data)
weather_1998_2018Feb = weather_1998_2018Feb[weather_1998_2018Feb['Date/Time'] <= '2017-12-01']

# # to filter the 5 provinces
filter = ['Quebec', 'Ontario', 'British Columbia', 'Alberta', 'Saskatchewan']
weather_1998_2018Feb = weather_1998_2018Feb[weather_1998_2018Feb['provincename'].isin(filter)]
print(weather_1998_2018Feb['provincename'].unique())

# # to remove data from Feb 2024
weather_2018_2024 = weather_2018_2024[weather_2018_2024['Date/Time'] <= '2024-01-01']
# Out:
# ['Quebec' 'Ontario' 'Saskatchewan' 'Alberta' 'British Columbia']

# %%
# to check date range of productivity

print(prod_clean['Date/Time'].min())
print(prod_clean['Date/Time'].max())
# Out:
# 1998-01-01 00:00:00
# 2021-12-01 00:00:00

# %%
# to check date range of final weather

print(weather_1998_2018Feb['Date/Time'].min())
print(weather_1998_2018Feb['Date/Time'].max())

print(weather_2018_2024['Date/Time'].min())
print(weather_2018_2024['Date/Time'].max())
# Out:
# 1998-01-01 00:00:00
# 2017-12-01 00:00:00
# 2018-01-01 00:00:00
# 2024-01-01 00:00:00

# %%
# to merge the 2 weather datasets
merged_weather = pd.concat([weather_1998_2018Feb, weather_2018_2024])
merged_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79262 entries, 3599 to 24271
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude                  79262 non-null  float64
#  1   Latitude                   79262 non-null  float64
#  2   Station Name               79262 non-null  object
#  3   Climate ID                 79262 non-null  object
#  4   Date/Time                  79262 non-null  datetime64[ns]
#  5   Year                       79262 non-null  int64
#  6   Month                      79262 non-null  int64
#  7   Mean Max Temp (°C)         76868 non-null  float64
#  8   Mean Max Temp Flag         54990 non-null  object
#  9   Mean Min Temp (°C)         76883 non-null  float64
#  10  Mean Min Temp Flag         54990 non-null  object
#  11  Mean Temp (°C)             75971 non-null  float64
#  12  Mean Temp Flag             54990 non-null  object
#  13  Extr Max Temp (°C)         76868 non-null  float64
#  14  Extr Max Temp Flag         54990 non-null  object
#  15  Extr Min Temp (°C)         76883 non-null  float64
#  16  Extr Min Temp Flag         54990 non-null  object
#  17  Total Rain (mm)            79262 non-null  float64
#  18  Total Rain Flag            54990 non-null  object
#  19  Total Snow (cm)            79262 non-null  float64
#  20  Total Snow Flag            54990 non-null  object
#  21  Total Precip (mm)          79262 non-null  float64
#  22  Total Precip Flag          54990 non-null  object
#  23  Snow Grnd Last Day (cm)    68555 non-null  float64
#  24  Snow Grnd Last Day Flag    54990 non-null  object
#  25  Dir of Max Gust (10s deg)  79262 non-null  float64
#  26  Dir of Max Gust Flag       54990 non-null  object
#  27  Spd of Max Gust (km/h)     79262 non-null  float64
#  28  Spd of Max Gust Flag       54990 non-null  object
#  29  GeoUID                     79262 non-null  int64
#  30  Region.Name                79262 non-null  object
#  31  provincename               79262 non-null  object
# dtypes: datetime64[ns](1), float64(13), int64(3), object(15)
# memory usage: 20.0+ MB

# %%
# to check shape of the datasets
print(prod_clean.shape)
print(merged_weather.shape)
# Out:
# (993600, 22)
# (79262, 32)

# %%
# to merge data:

merged_data = pd.merge(prod_clean, 
                       merged_weather,
                       on = ['GeoUID', 'Date/Time', 'provincename'],
                       how = 'right'
)
###### UPDATED: TO REVERT BACK IF DOESN'T WORK!!! how: from right to outer
    # used 'right' to only get productivity data that have weather data
    # not all GeoUID have weather data; we won't be able to forecast productivity for those GeoUID without the weather data

# %%
# to check shape of the datasets
print(prod_clean.shape)
print(merged_weather.shape)
print(merged_data.shape)
# Out:
# (993600, 22)
# (79262, 32)
# (79262, 51)

# %%
# to check date range
print(merged_data['Date/Time'].min())
print(merged_data['Date/Time'].max())
# Out:
# 1998-01-01 00:00:00
# 2024-01-01 00:00:00

# %%
# to remove unnecessary columns

merged_data.drop(columns = ['Date', 'Year', 'Month',
                            'census_year_ref', 'Dominant_NAICS',
                            'colourval'],
                 inplace = True)

# %%
# to arrange columns

columns_to_move = ['provincename', 'Longitude', 'Latitude', 'Region.Name', 'Date/Time']
remaining_columns = [col for col in merged_data.columns if col not in columns_to_move]
new_order = columns_to_move + remaining_columns
merged_data = merged_data[new_order]

# %%
# remove flag columns
flag_columns = [col for col in merged_data.columns if 'Flag' in col]
merged_data = merged_data.drop(columns = flag_columns)

# %%
# to remove stations that does not have productivity data
filter = ['KEMANO',
    'MCINNES ISLAND',
    'QUATSINO',
    'QUATSINO LIGHTSTATION',
    'SARTINE ISLAND (AUT)',
    'CHALK RIVER AECL',
    'OTTAWA CDA',
    "L'ETAPE"]
merged_data = merged_data[~merged_data['Station Name'].isin(filter)]
# print(merged_data['provincename'].unique())
print(merged_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78046 entries, 0 to 79261
# Data columns (total 34 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   provincename                                                                       78046 non-null  object
#  1   Longitude                                                                          78046 non-null  float64
#  2   Latitude                                                                           78046 non-null  float64
#  3   Region.Name                                                                        78046 non-null  object
#  4   Date/Time                                                                          78046 non-null  datetime64[ns]
#  5   Utilities                                                                          70210 non-null  float64
#  6   Construction                                                                       70210 non-null  float64
#  7   Manufacturing                                                                      70210 non-null  float64
#  8   Transportation and warehousing                                                     70210 non-null  float64
#  9   Educational services                                                               70210 non-null  float64
#  10  Health care and social assistance                                                  70210 non-null  float64
#  11  Accommodation and food services                                                    70210 non-null  float64
#  12  Other services except public administration                                        70210 non-null  float64
#  13  Public administration                                                              70210 non-null  float64
#  14  Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction  70210 non-null  float64
#  15  Wholesale trade Retail trade                                                       70210 non-null  float64
#  16  Finance and insurance, real estate and rental and leasing                          70210 non-null  float64
#  17  Professional scientific and technical services                                     70210 non-null  float64
#  18  Information culture and recreation                                                 70210 non-null  float64
#  19  Population                                                                         70210 non-null  float64
#  20  GeoUID                                                                             78046 non-null  int64
#  21  Station Name                                                                       78046 non-null  object
#  22  Climate ID                                                                         78046 non-null  object
#  23  Mean Max Temp (°C)                                                                 75690 non-null  float64
#  24  Mean Min Temp (°C)                                                                 75705 non-null  float64
#  25  Mean Temp (°C)                                                                     74793 non-null  float64
#  26  Extr Max Temp (°C)                                                                 75690 non-null  float64
#  27  Extr Min Temp (°C)                                                                 75705 non-null  float64
#  28  Total Rain (mm)                                                                    78046 non-null  float64
#  29  Total Snow (cm)                                                                    78046 non-null  float64
#  30  Total Precip (mm)                                                                  78046 non-null  float64
#  31  Snow Grnd Last Day (cm)                                                            67514 non-null  float64
#  32  Dir of Max Gust (10s deg)                                                          78046 non-null  float64
#  33  Spd of Max Gust (km/h)                                                             78046 non-null  float64
# dtypes: datetime64[ns](1), float64(28), int64(1), object(4)
# memory usage: 20.8+ MB
# None

# %%
merged_data['Snow Grnd Last Day (cm)'].fillna(0, inplace = True)

# %%
merged_data.isnull().sum()
# Out:
# provincename                                                                            0
# Longitude                                                                               0
# Latitude                                                                                0
# Region.Name                                                                             0
# Date/Time                                                                               0
# Utilities                                                                            7836
# Construction                                                                         7836
# Manufacturing                                                                        7836
# Transportation and warehousing                                                       7836
# Educational services                                                                 7836
# Health care and social assistance                                                    7836
# Accommodation and food services                                                      7836
# Other services except public administration                                          7836
# Public administration                                                                7836
# Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction    7836
# Wholesale trade Retail trade                                                         7836
# Finance and insurance, real estate and rental and leasing                            7836
# Professional scientific and technical services                                       7836
# Information culture and recreation                                                   7836
# Population                                                                           7836
# GeoUID                                                                                  0
# Station Name                                                                            0
# Climate ID                                                                              0
# Mean Max Temp (°C)                                                                   2356
# Mean Min Temp (°C)                                                                   2341
# Mean Temp (°C)                                                                       3253
# Extr Max Temp (°C)                                                                   2356
# Extr Min Temp (°C)                                                                   2341
# Total Rain (mm)                                                                         0
# Total Snow (cm)                                                                         0
# Total Precip (mm)                                                                       0
# Snow Grnd Last Day (cm)                                                                 0
# Dir of Max Gust (10s deg)                                                               0
# Spd of Max Gust (km/h)                                                                  0
# dtype: int64

# %%
# columns
columns_list = [
    'provincename',
    'Longitude',
    'Latitude',
    'Region.Name',
    'Date/Time',
    'Population',
    'GeoUID',
    'Station Name',
    'Climate ID',
    'Mean Max Temp (°C)',
    'Mean Min Temp (°C)',
    'Mean Temp (°C)',
    'Extr Max Temp (°C)',
    'Extr Min Temp (°C)',
    'Total Rain (mm)',
    'Total Snow (cm)',
    'Total Precip (mm)',
    'Snow Grnd Last Day (cm)',
    'Dir of Max Gust (10s deg)',
    'Spd of Max Gust (km/h)'
]

#melting the DataFrame to convert "Productivity areas" columns into rows
merged_data = pd.melt(merged_data, id_vars=columns_list, var_name='productivity_sector', value_name='GDP_Value')

#checking changes
merged_data
# Out:
#          provincename  Longitude  Latitude              Region.Name  \
# 0              Quebec     -78.28     48.80               Berry (MÉ)
# 1              Quebec     -78.28     48.80               Berry (MÉ)
# 2              Quebec     -78.28     48.80               Berry (MÉ)
# 3              Quebec     -78.28     48.80               Berry (MÉ)
# 4              Quebec     -78.28     48.80               Berry (MÉ)
# ...               ...        ...       ...                      ...
# 1092639  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
# 1092640  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
# 1092641  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
# 1092642  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
# 1092643  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
#
#          Date/Time  Population   GeoUID Station Name Climate ID  \
# 0       1998-01-01       538.0  2488070    LAC BERRY    709CEE9
# 1       1998-02-01       538.0  2488070    LAC BERRY    709CEE9
# 2       1998-03-01       538.0  2488070    LAC BERRY    709CEE9
# 3       1998-04-01       538.0  2488070    LAC BERRY    709CEE9
# 4       1998-05-01       538.0  2488070    LAC BERRY    709CEE9
# ...            ...         ...      ...          ...        ...
# 1092639 2023-09-01         NaN  4701036        OXBOW    4015800
# 1092640 2023-10-01         NaN  4701036        OXBOW    4015800
# 1092641 2023-11-01         NaN  4701036        OXBOW    4015800
# 1092642 2023-12-01         NaN  4701036        OXBOW    4015800
# 1092643 2024-01-01         NaN  4701036        OXBOW    4015800
#
#          Mean Max Temp (°C)  ...  Extr Max Temp (°C)  Extr Min Temp (°C)  \
# 0                 -8.400000  ...                 4.0               -39.0
# 1                 -1.100000  ...                 8.0               -37.0
# 2                  0.800000  ...                16.0               -35.0
# 3                 11.000000  ...                23.0               -12.0
# 4                 20.800000  ...                32.0                -5.0
# ...                     ...  ...                 ...                 ...
# 1092639           22.783333  ...                33.5                 1.0
# 1092640            9.250000  ...                21.0               -18.0
# 1092641            2.611111  ...                13.5               -17.5
# 1092642            0.648148  ...                11.5               -20.0
# 1092643           -9.428571  ...                 9.5               -36.0
#
#          Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  \
# 0                    1.0             42.0               43.0
# 1                    0.0             24.0               24.0
# 2                   62.4             31.0               93.4
# 3                   23.0              2.0               25.0
# 4                   33.3              0.0               33.3
# ...                  ...              ...                ...
# 1092639             21.4              0.0               21.4
# 1092640             42.8             25.0               67.8
# 1092641              4.0              6.0               10.0
# 1092642              9.6             11.0               20.6
# 1092643              0.0              3.0                3.0
#
#          Snow Grnd Last Day (cm)  Dir of Max Gust (10s deg)  \
# 0                           52.0                        0.0
# 1                           52.0                        0.0
# 2                           22.0                        0.0
# 3                            0.0                        0.0
# 4                            0.0                        0.0
# ...                          ...                        ...
# 1092639                      0.0                        0.0
# 1092640                     16.0                        0.0
# 1092641                      0.0                        0.0
# 1092642                      5.0                        0.0
# 1092643                      9.0                        0.0
#
#          Spd of Max Gust (km/h)                 productivity_sector  GDP_Value
# 0                           0.0                           Utilities        0.0
# 1                           0.0                           Utilities        0.0
# 2                           0.0                           Utilities        0.0
# 3                           0.0                           Utilities        0.0
# 4                           0.0                           Utilities        0.0
# ...                         ...                                 ...        ...
# 1092639                     0.0  Information culture and recreation        NaN
# 1092640                     0.0  Information culture and recreation        NaN
# 1092641                     0.0  Information culture and recreation        NaN
# 1092642                     0.0  Information culture and recreation        NaN
# 1092643                     0.0  Information culture and recreation        NaN
#
# [1092644 rows x 22 columns]

# %%
merged_data.isnull().sum()
# Out:
# provincename                      0
# Longitude                         0
# Latitude                          0
# Region.Name                       0
# Date/Time                         0
# Population                   109704
# GeoUID                            0
# Station Name                      0
# Climate ID                        0
# Mean Max Temp (°C)            32984
# Mean Min Temp (°C)            32774
# Mean Temp (°C)                45542
# Extr Max Temp (°C)            32984
# Extr Min Temp (°C)            32774
# Total Rain (mm)                   0
# Total Snow (cm)                   0
# Total Precip (mm)                 0
# Snow Grnd Last Day (cm)           0
# Dir of Max Gust (10s deg)         0
# Spd of Max Gust (km/h)            0
# productivity_sector               0
# GDP_Value                    109704
# dtype: int64

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092644 entries, 0 to 1092643
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   provincename               1092644 non-null  object
#  1   Longitude                  1092644 non-null  float64
#  2   Latitude                   1092644 non-null  float64
#  3   Region.Name                1092644 non-null  object
#  4   Date/Time                  1092644 non-null  datetime64[ns]
#  5   Population                 982940 non-null   float64
#  6   GeoUID                     1092644 non-null  int64
#  7   Station Name               1092644 non-null  object
#  8   Climate ID                 1092644 non-null  object
#  9   Mean Max Temp (°C)         1059660 non-null  float64
#  10  Mean Min Temp (°C)         1059870 non-null  float64
#  11  Mean Temp (°C)             1047102 non-null  float64
#  12  Extr Max Temp (°C)         1059660 non-null  float64
#  13  Extr Min Temp (°C)         1059870 non-null  float64
#  14  Total Rain (mm)            1092644 non-null  float64
#  15  Total Snow (cm)            1092644 non-null  float64
#  16  Total Precip (mm)          1092644 non-null  float64
#  17  Snow Grnd Last Day (cm)    1092644 non-null  float64
#  18  Dir of Max Gust (10s deg)  1092644 non-null  float64
#  19  Spd of Max Gust (km/h)     1092644 non-null  float64
#  20  productivity_sector        1092644 non-null  object
#  21  GDP_Value                  982940 non-null   float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(5)
# memory usage: 183.4+ MB

# %% [markdown]
# #### Handling the missing values for temp columns. Now as the temperature is essential for our analysis, we can"t staright up eliminate the null values, therefore the best way we could come up with was to take a mean of all the temperature of that months and filling the null values with the corresponding months mean we calculate.

# %%
#Columns with missing values
columns_with_missing_values = ['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)', 'Extr Min Temp (°C)']

#Create a 'Month' column from 'Date/Time'
merged_data['Month'] = merged_data['Date/Time'].dt.month

#Iterate through each column and fill missing values with the mean of the corresponding months
for column in columns_with_missing_values:
    # Create a mask for missing values in the current column
    missing_values_mask = merged_data[column].isnull()
    
    # Calculate the mean for each month in the column
    monthly_means = merged_data.groupby('Month')[column].mean()
    
    # Fill missing values with the mean of the corresponding month
    merged_data.loc[missing_values_mask, column] = merged_data.loc[missing_values_mask, 'Month'].map(monthly_means)

# Drop the 'Month' column if you don't want to keep it
merged_data.drop(columns=['Month'], inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# provincename                      0
# Longitude                         0
# Latitude                          0
# Region.Name                       0
# Date/Time                         0
# Population                   109704
# GeoUID                            0
# Station Name                      0
# Climate ID                        0
# Mean Max Temp (°C)                0
# Mean Min Temp (°C)                0
# Mean Temp (°C)                    0
# Extr Max Temp (°C)                0
# Extr Min Temp (°C)                0
# Total Rain (mm)                   0
# Total Snow (cm)                   0
# Total Precip (mm)                 0
# Snow Grnd Last Day (cm)           0
# Dir of Max Gust (10s deg)         0
# Spd of Max Gust (km/h)            0
# productivity_sector               0
# GDP_Value                    109704
# dtype: int64

# %%
# to ouput data

csv_path = 'merged_temp_clean_data.csv'
merged_data.to_csv(csv_path,
                   index = False)

# this data contains the geojson, weather, and productivity

# %% [markdown]
# #### From here is Time series analysis

# %%
merged_filtered = merged_data[merged_data['Date/Time'].dt.year <= 2021].copy()

# %%
merged_filtered.isnull().sum()
# Out:
# provincename                 0
# Longitude                    0
# Latitude                     0
# Region.Name                  0
# Date/Time                    0
# Population                   0
# GeoUID                       0
# Station Name                 0
# Climate ID                   0
# Mean Max Temp (°C)           0
# Mean Min Temp (°C)           0
# Mean Temp (°C)               0
# Extr Max Temp (°C)           0
# Extr Min Temp (°C)           0
# Total Rain (mm)              0
# Total Snow (cm)              0
# Total Precip (mm)            0
# Snow Grnd Last Day (cm)      0
# Dir of Max Gust (10s deg)    0
# Spd of Max Gust (km/h)       0
# productivity_sector          0
# GDP_Value                    0
# dtype: int64

# %%
# Explore data distribution and summary statistics
print(merged_filtered.describe())

# Visualize climate variables over time
merged_filtered['Mean Max Temp (°C)'].plot(label='Mean Max Temp')
plt.title('Mean Max Temp Over Time')
plt.show()
# Out:
#            Longitude       Latitude     Population        GeoUID  \
# count  982940.000000  982940.000000  982940.000000  9.829400e+05
# mean      -99.222596      48.973597   30283.697564  4.268813e+06
# std        22.010013       3.365611  108218.961134  1.403919e+06
# min      -136.370000      42.040000      41.000000  2.403005e+06
# 25%      -119.720000      46.050000    1044.000000  2.480015e+06
# 50%      -107.150000      49.170000    3824.000000  4.711042e+06
# 75%       -74.350000      51.080000   11249.000000  5.909032e+06
# max       -64.200000      59.570000  934243.000000  5.957022e+06
#
#        Mean Max Temp (°C)  Mean Min Temp (°C)  Mean Temp (°C)  \
# count       982940.000000       982940.000000   982940.000000
# mean            10.419499            0.599095        5.507649
# std             10.623589            9.623054        9.917053
# min            -24.600000          -36.000000      -29.637500
# 25%              0.700000           -5.800000       -1.236978
# 50%             10.500000            1.500000        6.000000
# 75%             20.000000            8.400000       14.180645
# max             34.880952           21.016667       27.090476
#
#        Extr Max Temp (°C)  Extr Min Temp (°C)  Total Rain (mm)  \
# count       982940.000000       982940.000000    982940.000000
# mean            18.958648           -7.799768        54.151770
# std             10.686706           13.097798        80.314297
# min            -22.000000          -50.500000         0.000000
# 25%             10.000000          -17.500000         0.000000
# 50%             20.000000           -3.500000        27.700000
# 75%             28.500000            2.000000        79.800000
# max             47.000000           17.100000      1185.400000
#
#        Total Snow (cm)  Total Precip (mm)  Snow Grnd Last Day (cm)  \
# count    982940.000000      982940.000000            982940.000000
# mean         10.699734          73.927176                 5.858354
# std          23.782507          82.202253                20.401887
# min           0.000000           0.000000                 0.000000
# 25%           0.000000          21.200000                 0.000000
# 50%           0.000000          55.400000                 0.000000
# 75%          10.000000          98.800000                 0.000000
# max         473.000000        1220.400000               955.000000
#
#        Dir of Max Gust (10s deg)  Spd of Max Gust (km/h)      GDP_Value
# count              982940.000000           982940.000000  982940.000000
# mean                    2.466472                6.982339      96.307563
# std                     7.781046               21.506831     479.677649
# min                     0.000000                0.000000       0.000000
# 25%                     0.000000                0.000000       1.696856
# 50%                     0.000000                0.000000       7.727141
# 75%                     0.000000                0.000000      32.144532
# max                    36.000000              207.000000   14853.664176

# %%
def calculate_mse(actual, predicted):
    """
    Calculate Mean Squared Error (MSE).

    Parameters:
    - actual: array-like, actual values
    - predicted: array-like, predicted values

    Returns:
    - mse: float, Mean Squared Error
    """
    squared_errors = (actual - predicted)**2
    mse = squared_errors.mean()
    return mse


# Use seasonal_decompose to decompose the time series with additive model
result_additive = seasonal_decompose(time_series, model='additive', period=12)

# Calculate MSE for the additive model
mse_additive = calculate_mse(time_series, result_additive.resid.dropna())

mse_additive
# Out:
# 144.69472398862555

# %%
# Selecting Ontario data for a specific province and climate variable (Mean Max Temp)
AB_prov_data = merged_filtered[merged_filtered['provincename'] == 'Alberta']
time_series = AB_prov_data['Mean Max Temp (°C)']

# Ensure the 'Date/Time' column is in datetime format
AB_prov_data['Date/Time'] = pd.to_datetime(AB_prov_data['Date/Time'])

# %%
all_columns  = AB_prov_data.columns.tolist()
print(all_columns)
# Out:
# ['provincename', 'Longitude', 'Latitude', 'Region.Name', 'Date/Time', 'Population', 'GeoUID', 'Station Name', 'Climate ID', 'Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)', 'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)', 'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)', 'productivity_sector', 'GDP_Value', 'Mean Max Temp (°C)_lag1']

# %%
# Plot time series for climate variables
AB_prov_data['Mean Max Temp (°C)'].plot(label='Mean Max Temp')
plt.show()

# %%
# Decompose time series to observe trends, seasonality, and residuals
result = seasonal_decompose(AB_prov_data['Mean Max Temp (°C)'], model='additive', period=12)
result.plot()
plt.show()

# %%
correlation_matrix = AB_prov_data.corr()
correlation_matrix
# Out:
#                            Longitude  Latitude  Population    GeoUID  \
# Longitude                   1.000000 -0.238256    0.022151 -0.574384
# Latitude                   -0.238256  1.000000    0.125023  0.786670
# Population                  0.022151  0.125023    1.000000  0.079307
# GeoUID                     -0.574384  0.786670    0.079307  1.000000
# Mean Max Temp (°C)          0.028917 -0.133711   -0.002638 -0.130505
# Mean Min Temp (°C)          0.066664 -0.107302    0.025396 -0.107599
# Mean Temp (°C)              0.047143 -0.122768    0.010690 -0.121236
# Extr Max Temp (°C)          0.052204 -0.130231    0.005828 -0.148749
# Extr Min Temp (°C)          0.061551 -0.071560    0.023839 -0.081382
# Total Rain (mm)             0.020898  0.001784    0.009182 -0.002162
# Total Snow (cm)            -0.057017  0.033146    0.018143  0.100395
# Total Precip (mm)          -0.067082  0.040421    0.006219  0.072310
# Snow Grnd Last Day (cm)    -0.124354  0.141701    0.031217  0.184066
# Dir of Max Gust (10s deg)   0.058764  0.011058   -0.003775 -0.010337
# Spd of Max Gust (km/h)      0.072522 -0.070804   -0.015883 -0.066907
# GDP_Value                   0.025252  0.123054    0.772578  0.073754
#
#                            Mean Max Temp (°C)  Mean Min Temp (°C)  \
# Longitude                            0.028917            0.066664
# Latitude                            -0.133711           -0.107302
# Population                          -0.002638            0.025396
# GeoUID                              -0.130505           -0.107599
# Mean Max Temp (°C)                   1.000000            0.945233
# Mean Min Temp (°C)                   0.945233            1.000000
# Mean Temp (°C)                       0.987868            0.984112
# Extr Max Temp (°C)                   0.938902            0.827162
# Extr Min Temp (°C)                   0.875261            0.955945
# Total Rain (mm)                      0.427813            0.465723
# Total Snow (cm)                     -0.349738           -0.335640
# Total Precip (mm)                    0.401230            0.434761
# Snow Grnd Last Day (cm)             -0.355197           -0.371895
# Dir of Max Gust (10s deg)           -0.015448           -0.047588
# Spd of Max Gust (km/h)              -0.017037           -0.042644
# GDP_Value                           -0.003513            0.017294
#
#                            Mean Temp (°C)  Extr Max Temp (°C)  \
# Longitude                        0.047143            0.052204
# Latitude                        -0.122768           -0.130231
# Population                       0.010690            0.005828
# GeoUID                          -0.121236           -0.148749
# Mean Max Temp (°C)               0.987868            0.938902
# Mean Min Temp (°C)               0.984112            0.827162
# Mean Temp (°C)                   1.000000            0.899172
# Extr Max Temp (°C)               0.899172            1.000000
# Extr Min Temp (°C)               0.925294            0.724007
# Total Rain (mm)                  0.451772            0.385646
# Total Snow (cm)                 -0.347899           -0.301202
# Total Precip (mm)                0.422711            0.379202
# Snow Grnd Last Day (cm)         -0.368122           -0.334369
# Dir of Max Gust (10s deg)       -0.030782            0.021654
# Spd of Max Gust (km/h)          -0.029324            0.016204
# GDP_Value                        0.006381            0.004680
#
#                            Extr Min Temp (°C)  Total Rain (mm)  \
# Longitude                            0.061551         0.020898
# Latitude                            -0.071560         0.001784
# Population                           0.023839         0.009182
# GeoUID                              -0.081382        -0.002162
# Mean Max Temp (°C)                   0.875261         0.427813
# Mean Min Temp (°C)                   0.955945         0.465723
# Mean Temp (°C)                       0.925294         0.451772
# Extr Max Temp (°C)                   0.724007         0.385646
# Extr Min Temp (°C)                   1.000000         0.451353
# Total Rain (mm)                      0.451353         1.000000
# Total Snow (cm)                     -0.348549        -0.143708
# Total Precip (mm)                    0.408101         0.768532
# Snow Grnd Last Day (cm)             -0.354127        -0.144761
# Dir of Max Gust (10s deg)           -0.064196        -0.215964
# Spd of Max Gust (km/h)              -0.063590        -0.217931
# GDP_Value                            0.016242         0.000149
#
#                            Total Snow (cm)  Total Precip (mm)  \
# Longitude                        -0.057017          -0.067082
# Latitude                          0.033146           0.040421
# Population                        0.018143           0.006219
# GeoUID                            0.100395           0.072310
# Mean Max Temp (°C)               -0.349738           0.401230
# Mean Min Temp (°C)               -0.335640           0.434761
# Mean Temp (°C)                   -0.347899           0.422711
# Extr Max Temp (°C)               -0.301202           0.379202
# Extr Min Temp (°C)               -0.348549           0.408101
# Total Rain (mm)                  -0.143708           0.768532
# Total Snow (cm)                   1.000000           0.064655
# Total Precip (mm)                 0.064655           1.000000
# Snow Grnd Last Day (cm)           0.303442          -0.050761
# Dir of Max Gust (10s deg)        -0.194067          -0.026850
# Spd of Max Gust (km/h)           -0.200299          -0.046544
# GDP_Value                         0.005649           0.002981
#
#                            Snow Grnd Last Day (cm)  Dir of Max Gust (10s deg)  \
# Longitude                                -0.124354                   0.058764
# Latitude                                  0.141701                   0.011058
# Population                                0.031217                  -0.003775
# GeoUID                                    0.184066                  -0.010337
# Mean Max Temp (°C)                       -0.355197                  -0.015448
# Mean Min Temp (°C)                       -0.371895                  -0.047588
# Mean Temp (°C)                           -0.368122                  -0.030782
# Extr Max Temp (°C)                       -0.334369                   0.021654
# Extr Min Temp (°C)                       -0.354127                  -0.064196
# Total Rain (mm)                          -0.144761                  -0.215964
# Total Snow (cm)                           0.303442                  -0.194067
# Total Precip (mm)                        -0.050761                  -0.026850
# Snow Grnd Last Day (cm)                   1.000000                   0.097184
# Dir of Max Gust (10s deg)                 0.097184                   1.000000
# Spd of Max Gust (km/h)                    0.063402                   0.895598
# GDP_Value                                 0.030289                   0.017903
#
#                            Spd of Max Gust (km/h)  GDP_Value
# Longitude                                0.072522   0.025252
# Latitude                                -0.070804   0.123054
# Population                              -0.015883   0.772578
# GeoUID                                  -0.066907   0.073754
# Mean Max Temp (°C)                      -0.017037  -0.003513
# Mean Min Temp (°C)                      -0.042644   0.017294
# Mean Temp (°C)                          -0.029324   0.006381
# Extr Max Temp (°C)                       0.016204   0.004680
# Extr Min Temp (°C)                      -0.063590   0.016242
# Total Rain (mm)                         -0.217931   0.000149
# Total Snow (cm)                         -0.200299   0.005649
# Total Precip (mm)                       -0.046544   0.002981
# Snow Grnd Last Day (cm)                  0.063402   0.030289
# Dir of Max Gust (10s deg)                0.895598   0.017903
# Spd of Max Gust (km/h)                   1.000000   0.005056
# GDP_Value                                0.005056   1.000000

# %%
# Plot heatmap of correlation matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plot scatter plot of each feature against the target variable
plt.figure(figsize=(12, 8))
for column in AB_prov_data.columns:
    if column != 'Mean Max Temp (°C)':
        sns.scatterplot(data=AB_prov_data, x=column, y='Mean Max Temp (°C)')
        plt.title(f'Scatter plot of {column} vs Mean Max Temp (°C)')
        plt.xlabel(column)
        plt.ylabel('Mean Max Temp (°C)')
        plt.show()

# %%
AB_prov_data['Mean Max Temp (°C)_lag1'] = AB_prov_data['Mean Max Temp (°C)'].shift(1)
AB_prov_data
# Out:
#         provincename  Longitude  Latitude                  Region.Name  \
# 31865        Alberta    -110.28     54.42               Cold Lake (CY)
# 31866        Alberta    -110.28     54.42               Cold Lake (CY)
# 31867        Alberta    -110.28     54.42               Cold Lake (CY)
# 31868        Alberta    -110.28     54.42               Cold Lake (CY)
# 31869        Alberta    -110.28     54.42               Cold Lake (CY)
# ...              ...        ...       ...                          ...
# 1073246      Alberta    -110.07     53.31  Vermilion River County (MD)
# 1073247      Alberta    -110.07     53.31  Vermilion River County (MD)
# 1073248      Alberta    -110.07     53.31  Vermilion River County (MD)
# 1073249      Alberta    -110.07     53.31  Vermilion River County (MD)
# 1073250      Alberta    -110.07     53.31  Vermilion River County (MD)
#
#          Date/Time  Population   GeoUID    Station Name Climate ID  \
# 31865   1998-01-01     14961.0  4812002     COLD LAKE A    3081680
# 31866   1998-02-01     14961.0  4812002     COLD LAKE A    3081680
# 31867   1998-03-01     14961.0  4812002     COLD LAKE A    3081680
# 31868   1998-04-01     14961.0  4812002     COLD LAKE A    3081680
# 31869   1998-05-01     14961.0  4812002     COLD LAKE A    3081680
# ...            ...         ...      ...             ...        ...
# 1073246 2021-08-01      8267.0  4810036  LLOYDMINSTER A    3013961
# 1073247 2021-09-01      8267.0  4810036  LLOYDMINSTER A    3013961
# 1073248 2021-10-01      8267.0  4810036  LLOYDMINSTER A    3013961
# 1073249 2021-11-01      8267.0  4810036  LLOYDMINSTER A    3013961
# 1073250 2021-12-01      8267.0  4810036  LLOYDMINSTER A    3013961
#
#          Mean Max Temp (°C)  ...  Extr Min Temp (°C)  Total Rain (mm)  \
# 31865            -14.700000  ...               -36.6              0.0
# 31866             -1.500000  ...               -16.1              0.2
# 31867              0.300000  ...               -29.7              0.2
# 31868             14.100000  ...                -5.4             24.4
# 31869             21.600000  ...                -1.1             13.8
# ...                     ...  ...                 ...              ...
# 1073246           23.564516  ...                 5.0             28.0
# 1073247           19.816667  ...                -1.0             14.0
# 1073248           10.919355  ...                -9.0             17.2
# 1073249            1.766667  ...               -20.0              2.0
# 1073250          -14.209677  ...               -37.0              0.0
#
#          Total Snow (cm)  Total Precip (mm)  Snow Grnd Last Day (cm)  \
# 31865               39.0               18.2                     20.0
# 31866                6.2                4.8                     21.0
# 31867                4.8                3.4                      0.0
# 31868                0.0               24.4                      0.0
# 31869                0.0               13.8                      0.0
# ...                  ...                ...                      ...
# 1073246              0.0               28.0                      0.0
# 1073247              0.0               14.0                      0.0
# 1073248              0.0               17.2                      0.0
# 1073249             15.4               21.4                      5.0
# 1073250             24.4               23.0                     17.0
#
#          Dir of Max Gust (10s deg)  Spd of Max Gust (km/h)  \
# 31865                          8.0                    37.0
# 31866                          0.0                     0.0
# 31867                         22.0                    54.0
# 31868                         10.0                    57.0
# 31869                         29.0                    69.0
# ...                            ...                     ...
# 1073246                        0.0                     0.0
# 1073247                        0.0                     0.0
# 1073248                        0.0                     0.0
# 1073249                        0.0                     0.0
# 1073250                        0.0                     0.0
#
#                         productivity_sector  GDP_Value  \
# 31865                             Utilities   1.891063
# 31866                             Utilities   1.945266
# 31867                             Utilities   1.880456
# 31868                             Utilities   1.948368
# 31869                             Utilities   2.535094
# ...                                     ...        ...
# 1073246  Information culture and recreation   4.932478
# 1073247  Information culture and recreation   4.479862
# 1073248  Information culture and recreation   4.448596
# 1073249  Information culture and recreation   4.339329
# 1073250  Information culture and recreation   4.107891
#
#          Mean Max Temp (°C)_lag1
# 31865                        NaN
# 31866                 -14.700000
# 31867                  -1.500000
# 31868                   0.300000
# 31869                  14.100000
# ...                          ...
# 1073246                25.177419
# 1073247                23.564516
# 1073248                19.816667
# 1073249                10.919355
# 1073250                 1.766667
#
# [148708 rows x 23 columns]

# %%
time_series
# Out:
# 31865     -14.700000
# 31866      -1.500000
# 31867       0.300000
# 31868      14.100000
# 31869      21.600000
#              ...
# 1073246    23.564516
# 1073247    19.816667
# 1073248    10.919355
# 1073249     1.766667
# 1073250   -14.209677
# Name: Mean Max Temp (°C), Length: 148708, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(AB_prov_data['Date/Time'], time_series, marker='o', linestyle='-', label='Mean Max Temp (°C)')
plt.title('Mean Max Temp Over Time')
plt.xlabel('Date')
plt.ylabel('Mean Max Temp (°C)')
plt.grid(True)
plt.legend()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# Check for stationarity
result = adfuller(time_series)
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -24.30376025052491
# p-value: 0.0

# %%
# Step 5: Calculate the differenced time series
time_series_diff = time_series.diff().dropna()

# Plot ACF and PACF for differenced time series
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(time_series_diff)
plot_pacf(time_series_diff)
plt.show()

# %%
time_series_diff
# Out:
# 31866      13.200000
# 31867       1.800000
# 31868      13.800000
# 31869       7.500000
# 31870       0.200000
#              ...
# 1073246    -1.612903
# 1073247    -3.747849
# 1073248    -8.897312
# 1073249    -9.152688
# 1073250   -15.976344
# Name: Mean Max Temp (°C), Length: 148707, dtype: float64

# %%
# Use seasonal decomposition to determine the seasonal order (p, d, q, s)
result = seasonal_decompose(time_series, model='additive', period=12)
seasonal_order = (result.seasonal.size - 1, 1, 1, 12)

# %%
import itertools
import statsmodels.api as sm

# Define the range of parameter values
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], s) for x in list(itertools.product(p, d, q)) for s in [12]]  # CHANGED!! Assuming seasonality of 12 for monthly data
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq [1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq [2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3])) 
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
# This generates a long list of all combinations for p,d,q,s values for SARIMAX. 
# This code take long time to execute be patient!!.

for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                mod = sm.tsa.statespace.SARIMAX(time_series, order=param, seasonal_order=param_seasonal, enforce_stationarity=False, enforce_invertibility=False)
                results = mod.fit()
                print('SARIMAX{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            except:
                continue

# %%
# model fiting
import statsmodels.api as sm 

mod = sm.tsa.statespace.SARIMAX(time_series, order= (1,1,1), seasonal_order = (1,1,1,12), enforce_stationarity=False, 
                                enforce_invertibility=False)
mod_results = mod.fit()

# %%
# Forecast future values
forecast_steps = 12  # Change this based on your desired forecast horizon
future_forecast = results.get_forecast(steps=forecast_steps)

# %%
# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(time_series.index, time_series, label='Actual')
plt.plot(future_forecast.predicted_mean.index, future_forecast.predicted_mean, color='red', label='Forecast')
plt.title(f'SARIMA Forecast for Ontario')
plt.xlabel('Date')
#plt.ylabel(climate_variable)
plt.legend()
plt.show()

# %%
mod_results.plot_diagnostics(figsize=(15,12))
plt.show()

# %% [markdown]
# **Standardized Residual for ‘M’:** The residuals seem to be randomly scattered around zero, which is a good sign. It suggests that your model is a good fit for the data as it’s capturing most of the information. There doesn’t appear to be any obvious pattern in the residuals, which indicates that the model’s assumptions are likely being met.
# **Histogram Plus Estimated Density:** The histogram and the estimated density line suggest that the residuals are approximately normally distributed, which is another good sign. This is one of the assumptions of many statistical models.
# **Normal Q-Q:** The points in the Q-Q plot are closely following the red line, which suggests that the residuals are normally distributed. This is another indication that the model’s assumptions are being met.
# **Correlogram:** The correlogram shows that the autocorrelation of the residuals is low for all lags. This is expected, as ideally, we want the residuals to be uncorrelated noise. If there were significant autocorrelations at certain lags, it would suggest that there is some pattern in the residuals that the model isn’t capturing.
# In **summary**, these graphs suggest that your model is doing a good job of capturing the patterns in the data. The residuals appear to be uncorrelated, normally distributed noise, which is what we would hope to see when our model is a good fit. However, always remember to validate these insights with domain knowledge and other statistical tests as needed. I hope this helps! Let me know if you have any other questions.

# %% [markdown]
# # The forecasting above is according to me not correct, it could be I'm not sure.
# # Below coding I'm trying different codes to predict from different soucres.

# %%
time_series
# Out:
# 20066      -2.700000
# 20067       3.400000
# 20068       3.800000
# 20069      13.400000
# 20070      22.100000
#              ...
# 1087846    27.612903
# 1087847    22.100000
# 1087848    15.967742
# 1087849     7.500000
# 1087850     1.333333
# Name: Mean Max Temp (°C), Length: 121814, dtype: float64

# %%
time_series.index = pd.to_datetime(time_series.index)
time_series.index.min()
# Out:
# Timestamp('1970-01-01 00:00:00.000020066')

# %%
min_date = time_series.min()
min_date
# Out:
# -24.4

# %%
time_series
# Out:
# 1970-01-01 00:00:00.000020066    -2.700000
# 1970-01-01 00:00:00.000020067     3.400000
# 1970-01-01 00:00:00.000020068     3.800000
# 1970-01-01 00:00:00.000020069    13.400000
# 1970-01-01 00:00:00.000020070    22.100000
#                                    ...
# 1970-01-01 00:00:00.001087846    27.612903
# 1970-01-01 00:00:00.001087847    22.100000
# 1970-01-01 00:00:00.001087848    15.967742
# 1970-01-01 00:00:00.001087849     7.500000
# 1970-01-01 00:00:00.001087850     1.333333
# Name: Mean Max Temp (°C), Length: 121814, dtype: float64

# %%
import pandas as pd

# Convert the index of the time series data to Timestamp type
time_series.index = pd.to_datetime(time_series.index)

# Find the minimum date in your time series data
min_date = time_series.index.min()

# Define the start date for prediction
start_date = max(pd.to_datetime('1998-01-01'), min_date)

# Check if '1998-01-01' is before the minimum date in the data
if start_date == min_date:
    print("Start date '1998-01-01' is before or equal to the minimum date in the data.")
else:
    # Provide a start date that is within the range of your data
    pred = results.get_prediction(start=start_date, dynamic=False)
    pred_ci = pred.conf_int()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\DAB200\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\pandas\_libs\index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: Timestamp('1998-01-01 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:247, in get_index_label_loc(key, index, row_labels)
#     246 if not isinstance(key, (int, np.integer)):
# --> 247     loc = row_labels.get_loc(key)
#     248 else:
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: Timestamp('1998-01-01 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:356, in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     355 try:
# --> 356     start, _, start_oos = get_index_label_loc(
#     357         start, base_index, data.row_labels
#     358     )
#     359 except KeyError:
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:279, in get_index_label_loc(key, index, row_labels)
#     278     except:
# --> 279         raise e
#     280 return loc, index, index_was_expanded
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:243, in get_index_label_loc(key, index, row_labels)
#     242 try:
# --> 243     loc, index, index_was_expanded = get_index_loc(key, index)
#     244 except KeyError as e:
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:193, in get_index_loc(key, index)
#     192 except (IndexError, ValueError) as e:
# --> 193     raise KeyError(str(e))
#     194 loc = key
#
# KeyError: 'only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[153], line 17
#      14     print("Start date '1998-01-01' is before or equal to the minimum date in the data.")
#      15 else:
#      16     # Provide a start date that is within the range of your data
# ---> 17     pred = results.get_prediction(start=start_date, dynamic=False)
#      18     pred_ci = pred.conf_int()
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3287, in MLEResults.get_prediction(self, start, end, dynamic, index, exog, extend_model, extend_kwargs, **kwargs)
#    3283     start = 0
#    3285 # Handle start, end, dynamic
#    3286 start, end, out_of_sample, prediction_index = (
# -> 3287     self.model._get_prediction_index(start, end, index))
#    3289 # Handle `dynamic`
#    3290 if isinstance(dynamic, (str, dt.datetime, pd.Timestamp)):
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834, in TimeSeriesModel._get_prediction_index(self, start, end, index, silent)
#     778 """
#     779 Get the location of a specific key in an index or model row labels
#     780
#    (...)
#     831 since we have required them to be full indexes, there is no ambiguity).
#     832 """
#     833 nobs = len(self.endog)
# --> 834 return get_prediction_index(
#     835     start,
#     836     end,
#     837     nobs,
#     838     base_index=self._index,
#     839     index=index,
#     840     silent=silent,
#     841     index_none=self._index_none,
#     842     index_generated=self._index_generated,
#     843     data=self.data,
#     844 )
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:360, in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     356     start, _, start_oos = get_index_label_loc(
#     357         start, base_index, data.row_labels
#     358     )
#     359 except KeyError:
# --> 360     raise KeyError(
#     361         "The `start` argument could not be matched to a"
#     362         " location related to the index of the data."
#     363     )
#     364 if end is None:
#     365     end = max(start, len(base_index) - 1)
#
# KeyError: 'The `start` argument could not be matched to a location related to the index of the data.'

# %%
# Convert the index of the time series data to Timestamp type
time_series.index = pd.to_datetime(time_series.index)

# Find the minimum date in your time series data
min_date = time_series.index.min()
min_date
# Out:
# Timestamp('1970-01-01 00:00:00.000020066')

# %%
pred = results.get_prediction(start=min_date, dynamic=False)
pred_ci = pred.conf_int()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\DAB200\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\pandas\_libs\index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: Timestamp('1970-01-01 00:00:00.000020066')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:247, in get_index_label_loc(key, index, row_labels)
#     246 if not isinstance(key, (int, np.integer)):
# --> 247     loc = row_labels.get_loc(key)
#     248 else:
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: Timestamp('1970-01-01 00:00:00.000020066')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:356, in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     355 try:
# --> 356     start, _, start_oos = get_index_label_loc(
#     357         start, base_index, data.row_labels
#     358     )
#     359 except KeyError:
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:279, in get_index_label_loc(key, index, row_labels)
#     278     except:
# --> 279         raise e
#     280 return loc, index, index_was_expanded
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:243, in get_index_label_loc(key, index, row_labels)
#     242 try:
# --> 243     loc, index, index_was_expanded = get_index_loc(key, index)
#     244 except KeyError as e:
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:193, in get_index_loc(key, index)
#     192 except (IndexError, ValueError) as e:
# --> 193     raise KeyError(str(e))
#     194 loc = key
#
# KeyError: 'only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 pred = results.get_prediction(start=min_date, dynamic=False)
#       2 pred_ci = pred.conf_int()
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3287, in MLEResults.get_prediction(self, start, end, dynamic, index, exog, extend_model, extend_kwargs, **kwargs)
#    3283     start = 0
#    3285 # Handle start, end, dynamic
#    3286 start, end, out_of_sample, prediction_index = (
# -> 3287     self.model._get_prediction_index(start, end, index))
#    3289 # Handle `dynamic`
#    3290 if isinstance(dynamic, (str, dt.datetime, pd.Timestamp)):
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834, in TimeSeriesModel._get_prediction_index(self, start, end, index, silent)
#     778 """
#     779 Get the location of a specific key in an index or model row labels
#     780
#    (...)
#     831 since we have required them to be full indexes, there is no ambiguity).
#     832 """
#     833 nobs = len(self.endog)
# --> 834 return get_prediction_index(
#     835     start,
#     836     end,
#     837     nobs,
#     838     base_index=self._index,
#     839     index=index,
#     840     silent=silent,
#     841     index_none=self._index_none,
#     842     index_generated=self._index_generated,
#     843     data=self.data,
#     844 )
#
# File ~\anaconda3\envs\DAB200\lib\site-packages\statsmodels\tsa\base\tsa_model.py:360, in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     356     start, _, start_oos = get_index_label_loc(
#     357         start, base_index, data.row_labels
#     358     )
#     359 except KeyError:
# --> 360     raise KeyError(
#     361         "The `start` argument could not be matched to a"
#     362         " location related to the index of the data."
#     363     )
#     364 if end is None:
#     365     end = max(start, len(base_index) - 1)
#
# KeyError: 'The `start` argument could not be matched to a location related to the index of the data.'
